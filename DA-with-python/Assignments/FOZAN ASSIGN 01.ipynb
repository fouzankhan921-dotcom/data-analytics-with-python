# %% [markdown]
# # ASSIGNMENT 01 "DATA ANALYTICS WITH PYTHON"

# %% [markdown]
# ## Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence character

# %%
name = "Muhammad Fozan Khan"
father_name = "Faisal Nadeem"
date_of_birth = "17/08/2007"

print(name)
print(father_name)
print(date_of_birth)
# Out:
# Muhammad Fozan Khan
# Faisal Nadeem
# 17/08/2007

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
bio = "My name is Muhammad Fozan Khan. I'm currently learning Data Analytics with Python, " \
"developing skills in data cleaning, analysis, visualization, and working with tools like Pandas and NumPy. " \
"I'm excited to use Python to turn data into meaningful insights and improve my analytical skills."

print(bio)
# Out:
# My name is Muhammad Fozan Khan. I'm currently learning Data Analytics with Python, developing skills in data cleaning, analysis, visualization, and working with tools like Pandas and NumPy. I'm excited to use Python to turn data into meaningful insights and improve my analytical skills.

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %% [markdown]
# Arthemtic Operators

# %%
a = 31
b = 18

print(a + b)   
print(a - b)    
print(a * b)    
print(a / b)  
print(a // b)  
print(a % b)    
print(a ** 2)
# Out:
# 49
# 13
# 558
# 1.7222222222222223
# 1
# 13
# 961

# %% [markdown]
# Comparison Operators

# %%
score = 96

print(score == 45)   
print(score != 56)    
print(score > 165)    
print(score >= 110)   
print(score < 122)
# Out:
# False
# True
# False
# False
# True

# %% [markdown]
# 4. Completes the following steps of small task:
#
#  - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables"
#
#  - Mention Variable of Total Marks and assign 300 to it"
#
#  - Calculate Percentage"

# %%
marks = {
    "English": 68, 
    "Islamiat": 73, 
    "Math": 95
         }

total_marks = 300
obtained_marks = 236
Percentage = (obtained_marks / total_marks) * 100
print("Percentage:", Percentage , "%")
# Out:
# Percentage: 78.66666666666666 %

# %% [markdown]
# 5. Take the values of two variables a and b, then swap their values without using a third variable and print the result before and after swapping

# %%
a = 7
b = 4
print("Before swapping: a =", a, "b =", b)
a = a + b
b = a - b
a = a - b
print("After swapping: a =", a, "b =", b)
# Out:
# Before swapping: a = 7 b = 4
# After swapping: a = 4 b = 7

# %% [markdown]
# 6. Take the radius of a circle from a variable and calculate its Area and Circumference (use pi = 3.14159)

# %%
radius = 7
pi = 3.14159
area = pi * radius ** 2
circumference = 2 * pi * radius
print("Area:", area)
print("Circumference:", circumference)
# Out:
# Area: 153.93791
# Circumference: 43.98226

# %% [markdown]
# 7. Take the price of an item and a discount percentage in variables, then calculate and print the discount amount and the final price after discount

# %%
price = 1000
discount_percentage = 15
discount_amount = (discount_percentage / 100) * price
final_price = price - discount_amount

print("Discount Amount:", discount_amount)
print("Final Price:", final_price)
# Out:
# Discount Amount: 150.0
# Final Price: 850.0
